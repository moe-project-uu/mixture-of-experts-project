# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

# 1) Go to /content and nuke any old clones
# %cd /content
# !rm -rf mixture-of-experts-project mixture_of_experts_project

# 2) Clone the *course* repo with the dash name
# !git clone https://github.com/moe-project-uu/mixture-of-experts-project.git

# 3) cd into it and checkout your branch
# %cd /content/mixture-of-experts-project
# !git checkout -f arokah
# !git branch   # this should show "* arokah"

# 4) Install deps into THIS Colab Python + editable project
# !{sys.executable} -m pip install -U pip setuptools wheel
# !{sys.executable} -m pip install -r requirements.txt
# !{sys.executable} -m pip install -e .

# 5) Make sure Python can see src/moe
SRC_DIR = os.path.join(os.getcwd(), "src")
if SRC_DIR not in sys.path:
    sys.path.append(SRC_DIR)

import moe
print("Imported moe from:", moe.__file__)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1276327177.py in <cell line: 0>()
#       3
#       4 # 1) Mount Drive
# ----> 5 drive.mount('/content/drive')
#       6
#       7 # 2) Go to /content and start clean
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     270             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     271         )
# --> 272       raise ValueError('mount failed' + extra_reason)
#     273     elif case == 4:
#     274       # Terminate the DriveFS binary before killing bash.
#
# ValueError: mount failed

# %%
import os
CKPT_ROOT = "/content/drive/MyDrive/moe_project/checkpoints"
os.makedirs(CKPT_ROOT, exist_ok=True)
print("CKPT_ROOT =", CKPT_ROOT)
# Out:
# CKPT_ROOT = /content/drive/MyDrive/moe_project/checkpoints

# %% [markdown]
# ### Train dense model
# result: /content/drive/MyDrive/moe_project/checkpoints/Dense/E50/
#     summary.json
#     model.pt
#     metrics.pt

# %%
#Note 512 is default width for dense model
#E50
# !python scripts/train_mnist.py \
    --FF_layer Dense \
    --epochs 50 \
    --ff_width 512 \
    --batch_size 128 \
    --ckpt_root "{CKPT_ROOT}"
# Out:
# 100% 170M/170M [00:01<00:00, 102MB/s]
# dataloaders metadata: {'mean': (0.4914, 0.4822, 0.4465), 'std': (0.247, 0.2435, 0.2616), 'num_classes': 10, 'sizes': {'train': 45000, 'val': 5000, 'test': 10000}}
# Epoch 1/50: 100% 352/352 [00:07<00:00, 44.94it/s]
# Epoch 001/50 | train_loss=1.6246 train_acc=40.09% | val_loss=1.4477 val_acc=52.30%
# Saved checkpoint: Dense val_acc=52.30%
# Epoch 2/50: 100% 352/352 [00:05<00:00, 62.93it/s]
# Epoch 002/50 | train_loss=1.1035 train_acc=61.20% | val_loss=1.1284 val_acc=60.58%
# Saved checkpoint: Dense val_acc=60.58%
# Epoch 3/50: 100% 352/352 [00:05<00:00, 62.70it/s]
# Epoch 003/50 | train_loss=0.8389 train_acc=71.41% | val_loss=1.1006 val_acc=63.54%
# Saved checkpoint: Dense val_acc=63.54%
# Epoch 4/50: 100% 352/352 [00:05<00:00, 62.70it/s]
# Epoch 004/50 | train_loss=0.6724 train_acc=77.31% | val_loss=0.7403 val_acc=74.26%
# Saved checkpoint: Dense val_acc=74.26%
# Epoch 5/50: 100% 352/352 [00:05<00:00, 63.02it/s]
# Epoch 005/50 | train_loss=0.5680 train_acc=80.97% | val_loss=0.7024 val_acc=76.02%
# Saved checkpoint: Dense val_acc=76.02%
# Epoch 6/50: 100% 352/352 [00:05<00:00, 64.61it/s]
# Epoch 006/50 | train_loss=0.4934 train_acc=83.49% | val_loss=0.9995 val_acc=69.90%
# Epoch 7/50: 100% 352/352 [00:05<00:00, 63.02it/s]
# Epoch 007/50 | train_loss=0.4410 train_acc=85.19% | val_loss=0.8137 val_acc=74.50%
# Epoch 8/50: 100% 352/352 [00:05<00:00, 62.58it/s]
# Epoch 008/50 | train_loss=0.3996 train_acc=86.73% | val_loss=0.6173 val_acc=79.72%
# Saved checkpoint: Dense val_acc=79.72%
# Epoch 9/50: 100% 352/352 [00:05<00:00, 63.81it/s]
# Epoch 009/50 | train_loss=0.3637 train_acc=87.70% | val_loss=0.6605 val_acc=78.32%
# Epoch 10/50: 100% 352/352 [00:05<00:00, 60.95it/s]
# Epoch 010/50 | train_loss=0.3381 train_acc=88.66% | val_loss=0.6988 val_acc=78.02%
# Epoch 11/50: 100% 352/352 [00:05<00:00, 63.08it/s]
# Epoch 011/50 | train_loss=0.3150 train_acc=89.45% | val_loss=0.6729 val_acc=78.40%
# Epoch 12/50: 100% 352/352 [00:05<00:00, 62.97it/s]
# Epoch 012/50 | train_loss=0.3081 train_acc=89.62% | val_loss=0.6707 val_acc=78.94%
# Epoch 13/50: 100% 352/352 [00:05<00:00, 63.57it/s]
# Epoch 013/50 | train_loss=0.2839 train_acc=90.37% | val_loss=0.6267 val_acc=79.80%
# Saved checkpoint: Dense val_acc=79.80%
# Epoch 14/50: 100% 352/352 [00:05<00:00, 63.98it/s]
# Epoch 014/50 | train_loss=0.2676 train_acc=91.05% | val_loss=0.6882 val_acc=78.06%
# Epoch 15/50: 100% 352/352 [00:05<00:00, 62.42it/s]
# Epoch 015/50 | train_loss=0.2575 train_acc=91.41% | val_loss=0.6438 val_acc=79.66%
# Epoch 16/50: 100% 352/352 [00:05<00:00, 64.75it/s]
# Epoch 016/50 | train_loss=0.2512 train_acc=91.60% | val_loss=0.7409 val_acc=77.76%
# Epoch 17/50: 100% 352/352 [00:05<00:00, 65.31it/s]
# Epoch 017/50 | train_loss=0.2305 train_acc=92.33% | val_loss=1.0270 val_acc=72.04%
# Epoch 18/50: 100% 352/352 [00:05<00:00, 64.08it/s]
# Epoch 018/50 | train_loss=0.2358 train_acc=92.17% | val_loss=0.7108 val_acc=78.02%
# Epoch 19/50: 100% 352/352 [00:05<00:00, 62.72it/s]
# Epoch 019/50 | train_loss=0.2220 train_acc=92.63% | val_loss=0.7323 val_acc=79.02%
# Epoch 20/50: 100% 352/352 [00:05<00:00, 65.20it/s]
# Epoch 020/50 | train_loss=0.2251 train_acc=92.52% | val_loss=0.8508 val_acc=74.90%
# Epoch 21/50: 100% 352/352 [00:05<00:00, 64.86it/s]
# Epoch 021/50 | train_loss=0.2189 train_acc=92.49% | val_loss=0.7175 val_acc=77.66%
# Epoch 22/50: 100% 352/352 [00:05<00:00, 64.83it/s]
# Epoch 022/50 | train_loss=0.2102 train_acc=92.99% | val_loss=0.6818 val_acc=78.72%
# Epoch 23/50: 100% 352/352 [00:05<00:00, 62.93it/s]
# Epoch 023/50 | train_loss=0.2163 train_acc=92.74% | val_loss=0.8960 val_acc=73.38%
# Epoch 24/50: 100% 352/352 [00:05<00:00, 63.43it/s]
# Epoch 024/50 | train_loss=0.2072 train_acc=92.97% | val_loss=0.6990 val_acc=79.82%
# Saved checkpoint: Dense val_acc=79.82%
# Epoch 25/50: 100% 352/352 [00:05<00:00, 64.70it/s]
# Epoch 025/50 | train_loss=0.2025 train_acc=93.14% | val_loss=0.7932 val_acc=77.08%
# Epoch 26/50: 100% 352/352 [00:05<00:00, 63.10it/s]
# Epoch 026/50 | train_loss=0.1998 train_acc=93.29% | val_loss=0.7282 val_acc=78.98%
# Epoch 27/50: 100% 352/352 [00:05<00:00, 63.54it/s]
# Epoch 027/50 | train_loss=0.1945 train_acc=93.38% | val_loss=0.6774 val_acc=78.82%
# Epoch 28/50: 100% 352/352 [00:05<00:00, 64.67it/s]
# Epoch 028/50 | train_loss=0.2045 train_acc=93.21% | val_loss=1.0328 val_acc=73.70%
# Epoch 29/50: 100% 352/352 [00:05<00:00, 64.54it/s]
# Epoch 029/50 | train_loss=0.2052 train_acc=93.10% | val_loss=0.7465 val_acc=77.52%
# Epoch 30/50: 100% 352/352 [00:05<00:00, 64.62it/s]
# Epoch 030/50 | train_loss=0.1965 train_acc=93.54% | val_loss=0.6395 val_acc=80.04%
# Saved checkpoint: Dense val_acc=80.04%
# Epoch 31/50: 100% 352/352 [00:05<00:00, 62.77it/s]
# Epoch 031/50 | train_loss=0.0492 train_acc=98.59% | val_loss=0.4335 val_acc=87.28%
# Saved checkpoint: Dense val_acc=87.28%
# Epoch 32/50: 100% 352/352 [00:05<00:00, 62.39it/s]
# Epoch 032/50 | train_loss=0.0105 train_acc=99.88% | val_loss=0.4472 val_acc=87.32%
# Saved checkpoint: Dense val_acc=87.32%
# Epoch 33/50: 100% 352/352 [00:05<00:00, 64.98it/s]
# Epoch 033/50 | train_loss=0.0056 train_acc=99.96% | val_loss=0.4581 val_acc=87.60%
# Saved checkpoint: Dense val_acc=87.60%
# Epoch 34/50: 100% 352/352 [00:05<00:00, 63.19it/s]
# Epoch 034/50 | train_loss=0.0041 train_acc=99.98% | val_loss=0.4595 val_acc=87.78%
# Saved checkpoint: Dense val_acc=87.78%
# Epoch 35/50: 100% 352/352 [00:05<00:00, 65.29it/s]
# Epoch 035/50 | train_loss=0.0033 train_acc=99.99% | val_loss=0.4601 val_acc=87.86%
# Saved checkpoint: Dense val_acc=87.86%
# Epoch 36/50: 100% 352/352 [00:05<00:00, 62.40it/s]
# Epoch 036/50 | train_loss=0.0027 train_acc=100.00% | val_loss=0.4561 val_acc=87.74%
# Epoch 37/50: 100% 352/352 [00:05<00:00, 64.94it/s]
# Epoch 037/50 | train_loss=0.0024 train_acc=100.00% | val_loss=0.4602 val_acc=87.78%
# Epoch 38/50: 100% 352/352 [00:05<00:00, 63.83it/s]
# Epoch 038/50 | train_loss=0.0025 train_acc=100.00% | val_loss=0.4560 val_acc=87.70%
# Epoch 39/50: 100% 352/352 [00:05<00:00, 63.85it/s]
# Epoch 039/50 | train_loss=0.0022 train_acc=100.00% | val_loss=0.4530 val_acc=87.58%
# Epoch 40/50: 100% 352/352 [00:05<00:00, 64.28it/s]
# Epoch 040/50 | train_loss=0.0022 train_acc=100.00% | val_loss=0.4528 val_acc=87.62%
# Epoch 41/50: 100% 352/352 [00:05<00:00, 64.25it/s]
# Epoch 041/50 | train_loss=0.0020 train_acc=100.00% | val_loss=0.4486 val_acc=87.80%
# Epoch 42/50: 100% 352/352 [00:05<00:00, 64.35it/s]
# Epoch 042/50 | train_loss=0.0021 train_acc=100.00% | val_loss=0.4532 val_acc=87.70%
# Epoch 43/50: 100% 352/352 [00:05<00:00, 64.67it/s]
# Epoch 043/50 | train_loss=0.0021 train_acc=100.00% | val_loss=0.4527 val_acc=87.70%
# Epoch 44/50: 100% 352/352 [00:05<00:00, 64.12it/s]
# Epoch 044/50 | train_loss=0.0020 train_acc=100.00% | val_loss=0.4498 val_acc=87.72%
# Epoch 45/50: 100% 352/352 [00:05<00:00, 65.54it/s]
# Epoch 045/50 | train_loss=0.0020 train_acc=100.00% | val_loss=0.4498 val_acc=87.76%
# Epoch 46/50: 100% 352/352 [00:05<00:00, 62.79it/s]
# Epoch 046/50 | train_loss=0.0019 train_acc=100.00% | val_loss=0.4515 val_acc=87.72%
# Epoch 47/50: 100% 352/352 [00:05<00:00, 64.26it/s]
# Epoch 047/50 | train_loss=0.0020 train_acc=100.00% | val_loss=0.4485 val_acc=87.74%
# Epoch 48/50: 100% 352/352 [00:05<00:00, 63.09it/s]
# Epoch 048/50 | train_loss=0.0019 train_acc=100.00% | val_loss=0.4493 val_acc=87.78%
# Epoch 49/50: 100% 352/352 [00:05<00:00, 64.97it/s]
# Epoch 049/50 | train_loss=0.0021 train_acc=100.00% | val_loss=0.4467 val_acc=87.80%
# Epoch 50/50: 100% 352/352 [00:05<00:00, 63.12it/s]
# Epoch 050/50 | train_loss=0.0019 train_acc=100.00% | val_loss=0.4463 val_acc=87.84%
# [FINAL TEST] loss=0.5225 acc=86.44%
#
# === Summary ===
# Width 512:
# M_A  (max train acc): 100.00%  at epoch 37
# G_A  (max val  acc): 87.86%  at epoch 35
# ETT(M_A) = 37,  ETT(G_A) = 35

# %% [markdown]
# ### Train softmoe
# result: /content/drive/MyDrive/moe_project/checkpoints/SoftMoE/E50-X8/
#     summary.json
#     model.pt
#     metrics.pt

# %%
#8 experts, 64 hidden width (0.125 * 512 = 64)
#E50-X8
# !python scripts/train_mnist.py \
    --FF_layer SoftMoE \
    --epochs 50 \
    --batch_size 128 \
    --num_experts 8 \
    --hidden_mult 0.125 \
    --temperature 1.0 \
    --softmoe_load_balance True \
    --softmoe_load_balance_coef 0.2 \
    --dropout_p 0.1 \
    --ckpt_root "{CKPT_ROOT}"
# Out:
# dataloaders metadata: {'mean': (0.4914, 0.4822, 0.4465), 'std': (0.247, 0.2435, 0.2616), 'num_classes': 10, 'sizes': {'train': 45000, 'val': 5000, 'test': 10000}}
# Epoch 1/50: 100% 352/352 [00:08<00:00, 43.03it/s]
# Epoch 001/50 | train_loss=1.6956 train_acc=37.02% | val_loss=1.4911 val_acc=48.78%
# Saved checkpoint: SoftMoE val_acc=48.78%
# Epoch 2/50: 100% 352/352 [00:07<00:00, 49.76it/s]
# Epoch 002/50 | train_loss=1.1511 train_acc=59.42% | val_loss=1.1784 val_acc=58.70%
# Saved checkpoint: SoftMoE val_acc=58.70%
# Epoch 3/50: 100% 352/352 [00:06<00:00, 50.57it/s]
# Epoch 003/50 | train_loss=0.8397 train_acc=70.99% | val_loss=0.7877 val_acc=73.10%
# Saved checkpoint: SoftMoE val_acc=73.10%
# Epoch 4/50: 100% 352/352 [00:07<00:00, 49.83it/s]
# Epoch 004/50 | train_loss=0.6530 train_acc=78.00% | val_loss=0.7426 val_acc=74.02%
# Saved checkpoint: SoftMoE val_acc=74.02%
# Epoch 5/50: 100% 352/352 [00:07<00:00, 49.23it/s]
# Epoch 005/50 | train_loss=0.5486 train_acc=81.50% | val_loss=0.7828 val_acc=73.80%
# Epoch 6/50: 100% 352/352 [00:06<00:00, 50.62it/s]
# Epoch 006/50 | train_loss=0.4703 train_acc=84.24% | val_loss=0.6589 val_acc=77.06%
# Saved checkpoint: SoftMoE val_acc=77.06%
# Epoch 7/50: 100% 352/352 [00:07<00:00, 50.24it/s]
# Epoch 007/50 | train_loss=0.4118 train_acc=86.39% | val_loss=0.6677 val_acc=76.48%
# Epoch 8/50: 100% 352/352 [00:07<00:00, 48.20it/s]
# Epoch 008/50 | train_loss=0.3837 train_acc=87.12% | val_loss=0.7807 val_acc=74.12%
# Epoch 9/50: 100% 352/352 [00:07<00:00, 49.85it/s]
# Epoch 009/50 | train_loss=0.3462 train_acc=88.39% | val_loss=0.9128 val_acc=71.18%
# Epoch 10/50: 100% 352/352 [00:06<00:00, 50.53it/s]
# Epoch 010/50 | train_loss=0.3252 train_acc=89.17% | val_loss=0.5785 val_acc=80.32%
# Saved checkpoint: SoftMoE val_acc=80.32%
# Epoch 11/50: 100% 352/352 [00:06<00:00, 51.50it/s]
# Epoch 011/50 | train_loss=0.2927 train_acc=90.33% | val_loss=0.6700 val_acc=78.50%
# Epoch 12/50: 100% 352/352 [00:07<00:00, 48.86it/s]
# Epoch 012/50 | train_loss=0.2875 train_acc=90.38% | val_loss=0.6539 val_acc=79.62%
# Epoch 13/50: 100% 352/352 [00:07<00:00, 48.14it/s]
# Epoch 013/50 | train_loss=0.2626 train_acc=91.13% | val_loss=0.6256 val_acc=79.34%
# Epoch 14/50: 100% 352/352 [00:07<00:00, 47.54it/s]
# Epoch 014/50 | train_loss=0.2537 train_acc=91.63% | val_loss=0.6255 val_acc=79.28%
# Epoch 15/50: 100% 352/352 [00:07<00:00, 49.67it/s]
# Epoch 015/50 | train_loss=0.2473 train_acc=91.80% | val_loss=0.6597 val_acc=79.02%
# Epoch 16/50: 100% 352/352 [00:06<00:00, 51.31it/s]
# Epoch 016/50 | train_loss=0.2390 train_acc=92.07% | val_loss=0.6216 val_acc=79.92%
# Epoch 17/50: 100% 352/352 [00:07<00:00, 48.99it/s]
# Epoch 017/50 | train_loss=0.2304 train_acc=92.41% | val_loss=0.5977 val_acc=81.08%
# Saved checkpoint: SoftMoE val_acc=81.08%
# Epoch 18/50: 100% 352/352 [00:07<00:00, 47.97it/s]
# Epoch 018/50 | train_loss=0.2225 train_acc=92.52% | val_loss=0.6860 val_acc=78.50%
# Epoch 19/50: 100% 352/352 [00:07<00:00, 49.19it/s]
# Epoch 019/50 | train_loss=0.2152 train_acc=93.01% | val_loss=0.8410 val_acc=74.64%
# Epoch 20/50: 100% 352/352 [00:07<00:00, 48.97it/s]
# Epoch 020/50 | train_loss=0.2187 train_acc=92.68% | val_loss=1.1070 val_acc=70.12%
# Epoch 21/50: 100% 352/352 [00:07<00:00, 49.82it/s]
# Epoch 021/50 | train_loss=0.2078 train_acc=93.19% | val_loss=0.8717 val_acc=75.96%
# Epoch 22/50: 100% 352/352 [00:07<00:00, 47.79it/s]
# Epoch 022/50 | train_loss=0.2093 train_acc=92.95% | val_loss=0.8667 val_acc=75.70%
# Epoch 23/50: 100% 352/352 [00:06<00:00, 50.32it/s]
# Epoch 023/50 | train_loss=0.2096 train_acc=93.10% | val_loss=0.7819 val_acc=77.08%
# Epoch 24/50: 100% 352/352 [00:06<00:00, 51.53it/s]
# Epoch 024/50 | train_loss=0.2027 train_acc=93.39% | val_loss=0.7928 val_acc=77.64%
# Epoch 25/50: 100% 352/352 [00:07<00:00, 50.20it/s]
# Epoch 025/50 | train_loss=0.2097 train_acc=93.09% | val_loss=0.7501 val_acc=78.52%
# Epoch 26/50: 100% 352/352 [00:06<00:00, 51.36it/s]
# Epoch 026/50 | train_loss=0.1980 train_acc=93.54% | val_loss=0.7588 val_acc=76.98%
# Epoch 27/50: 100% 352/352 [00:06<00:00, 50.30it/s]
# Epoch 027/50 | train_loss=0.1988 train_acc=93.52% | val_loss=0.6008 val_acc=81.42%
# Saved checkpoint: SoftMoE val_acc=81.42%
# Epoch 28/50: 100% 352/352 [00:06<00:00, 51.02it/s]
# Epoch 028/50 | train_loss=0.2074 train_acc=93.18% | val_loss=0.6868 val_acc=77.84%
# Epoch 29/50: 100% 352/352 [00:06<00:00, 50.40it/s]
# Epoch 029/50 | train_loss=0.1860 train_acc=93.91% | val_loss=0.8507 val_acc=76.08%
# Epoch 30/50: 100% 352/352 [00:06<00:00, 50.76it/s]
# Epoch 030/50 | train_loss=0.1991 train_acc=93.42% | val_loss=0.5984 val_acc=80.52%
# Epoch 31/50: 100% 352/352 [00:06<00:00, 50.46it/s]
# Epoch 031/50 | train_loss=0.0645 train_acc=98.27% | val_loss=0.4081 val_acc=87.52%
# Saved checkpoint: SoftMoE val_acc=87.52%
# Epoch 32/50: 100% 352/352 [00:07<00:00, 50.25it/s]
# Epoch 032/50 | train_loss=0.0166 train_acc=99.84% | val_loss=0.4056 val_acc=87.62%
# Saved checkpoint: SoftMoE val_acc=87.62%
# Epoch 33/50: 100% 352/352 [00:07<00:00, 48.30it/s]
# Epoch 033/50 | train_loss=0.0102 train_acc=99.95% | val_loss=0.4149 val_acc=87.60%
# Epoch 34/50: 100% 352/352 [00:07<00:00, 50.24it/s]
# Epoch 034/50 | train_loss=0.0079 train_acc=99.96% | val_loss=0.4118 val_acc=88.06%
# Saved checkpoint: SoftMoE val_acc=88.06%
# Epoch 35/50: 100% 352/352 [00:07<00:00, 47.81it/s]
# Epoch 035/50 | train_loss=0.0061 train_acc=99.99% | val_loss=0.4165 val_acc=87.80%
# Epoch 36/50: 100% 352/352 [00:07<00:00, 48.87it/s]
# Epoch 036/50 | train_loss=0.0054 train_acc=99.99% | val_loss=0.4176 val_acc=88.08%
# Saved checkpoint: SoftMoE val_acc=88.08%
# Epoch 37/50: 100% 352/352 [00:06<00:00, 50.73it/s]
# Epoch 037/50 | train_loss=0.0051 train_acc=99.99% | val_loss=0.4151 val_acc=88.18%
# Saved checkpoint: SoftMoE val_acc=88.18%
# Epoch 38/50: 100% 352/352 [00:06<00:00, 51.91it/s]
# Epoch 038/50 | train_loss=0.0044 train_acc=100.00% | val_loss=0.4180 val_acc=88.14%
# Epoch 39/50: 100% 352/352 [00:06<00:00, 50.39it/s]
# Epoch 039/50 | train_loss=0.0043 train_acc=99.99% | val_loss=0.4156 val_acc=87.96%
# Epoch 40/50: 100% 352/352 [00:07<00:00, 49.35it/s]
# Epoch 040/50 | train_loss=0.0042 train_acc=100.00% | val_loss=0.4126 val_acc=87.96%
# Epoch 41/50: 100% 352/352 [00:06<00:00, 50.98it/s]
# Epoch 041/50 | train_loss=0.0040 train_acc=100.00% | val_loss=0.4124 val_acc=88.10%
# Epoch 42/50: 100% 352/352 [00:06<00:00, 50.41it/s]
# Epoch 042/50 | train_loss=0.0039 train_acc=100.00% | val_loss=0.4165 val_acc=88.06%
# Epoch 43/50: 100% 352/352 [00:07<00:00, 47.22it/s]
# Epoch 043/50 | train_loss=0.0040 train_acc=100.00% | val_loss=0.4124 val_acc=88.14%
# Epoch 44/50: 100% 352/352 [00:07<00:00, 47.59it/s]
# Epoch 044/50 | train_loss=0.0039 train_acc=100.00% | val_loss=0.4177 val_acc=88.02%
# Epoch 45/50: 100% 352/352 [00:07<00:00, 49.91it/s]
# Epoch 045/50 | train_loss=0.0039 train_acc=100.00% | val_loss=0.4168 val_acc=88.08%
# Epoch 46/50: 100% 352/352 [00:07<00:00, 44.97it/s]
# Epoch 046/50 | train_loss=0.0038 train_acc=100.00% | val_loss=0.4164 val_acc=88.02%
# Epoch 47/50: 100% 352/352 [00:07<00:00, 47.46it/s]
# Epoch 047/50 | train_loss=0.0038 train_acc=100.00% | val_loss=0.4154 val_acc=88.08%
# Epoch 48/50: 100% 352/352 [00:06<00:00, 50.39it/s]
# Epoch 048/50 | train_loss=0.0039 train_acc=99.99% | val_loss=0.4157 val_acc=88.24%
# Saved checkpoint: SoftMoE val_acc=88.24%
# Epoch 49/50: 100% 352/352 [00:07<00:00, 49.62it/s]
# Epoch 049/50 | train_loss=0.0039 train_acc=100.00% | val_loss=0.4131 val_acc=88.16%
# Epoch 50/50: 100% 352/352 [00:07<00:00, 49.62it/s]
# Epoch 050/50 | train_loss=0.0038 train_acc=100.00% | val_loss=0.4114 val_acc=88.04%
# [FINAL TEST] loss=0.4559 acc=87.23%
#
# === Summary ===
# num_experts 8
# expert_width 64
# total_width  512
# M_A  (max train acc): 100.00%  at epoch 41
# G_A  (max val  acc): 88.24%  at epoch 48
# ETT(M_A) = 41,  ETT(G_A) = 48

# %% [markdown]
# ### Train SparseMoe (top2)
# result: /content/drive/MyDrive/moe_project/checkpoints/SparseMoE/E50-X8-K2/
#     summary.json
#     model.pt
#     metrics.pt

# %%
#8 experts, 64 hidden width (0.125 * 512 = 64), top2
#E50-X8-K2
# !python scripts/train_mnist.py \
    --FF_layer SparseMoE \
    --epochs 50 \
    --batch_size 128 \
    --num_experts 8 \
    --hidden_mult 0.125 \
    --sparsemoe_k 2 \
    --dropout_p 0.1\
    --sparsemoe_importance_coef 0.2 \
    --sparsemoe_load_coef 0.2\
    --ckpt_root "{CKPT_ROOT}"
# Out:
# dataloaders metadata: {'mean': (0.4914, 0.4822, 0.4465), 'std': (0.247, 0.2435, 0.2616), 'num_classes': 10, 'sizes': {'train': 45000, 'val': 5000, 'test': 10000}}
# Epoch 1/50: 100% 352/352 [00:12<00:00, 28.41it/s]
# Epoch 001/50 | train_loss=1.8188 train_acc=33.39% | val_loss=1.5714 val_acc=41.86%
# Saved checkpoint: SparseMoE val_acc=41.86%
# Epoch 2/50: 100% 352/352 [00:11<00:00, 30.74it/s]
# Epoch 002/50 | train_loss=1.2242 train_acc=58.77% | val_loss=0.9883 val_acc=63.20%
# Saved checkpoint: SparseMoE val_acc=63.20%
# Epoch 3/50: 100% 352/352 [00:11<00:00, 31.46it/s]
# Epoch 003/50 | train_loss=0.9347 train_acc=69.91% | val_loss=0.8998 val_acc=68.76%
# Saved checkpoint: SparseMoE val_acc=68.76%
# Epoch 4/50: 100% 352/352 [00:10<00:00, 33.60it/s]
# Epoch 004/50 | train_loss=0.7795 train_acc=75.91% | val_loss=0.8538 val_acc=71.02%
# Saved checkpoint: SparseMoE val_acc=71.02%
# Epoch 5/50: 100% 352/352 [00:10<00:00, 32.96it/s]
# Epoch 005/50 | train_loss=0.6750 train_acc=79.86% | val_loss=0.7342 val_acc=75.34%
# Saved checkpoint: SparseMoE val_acc=75.34%
# Epoch 6/50: 100% 352/352 [00:10<00:00, 32.00it/s]
# Epoch 006/50 | train_loss=0.5858 train_acc=82.99% | val_loss=0.9932 val_acc=67.44%
# Epoch 7/50: 100% 352/352 [00:11<00:00, 29.97it/s]
# Epoch 007/50 | train_loss=0.5300 train_acc=84.80% | val_loss=0.6230 val_acc=78.54%
# Saved checkpoint: SparseMoE val_acc=78.54%
# Epoch 8/50: 100% 352/352 [00:11<00:00, 31.66it/s]
# Epoch 008/50 | train_loss=0.4864 train_acc=86.42% | val_loss=0.5808 val_acc=80.72%
# Saved checkpoint: SparseMoE val_acc=80.72%
# Epoch 9/50: 100% 352/352 [00:11<00:00, 31.86it/s]
# Epoch 009/50 | train_loss=0.4547 train_acc=87.31% | val_loss=0.7214 val_acc=76.26%
# Epoch 10/50: 100% 352/352 [00:10<00:00, 32.04it/s]
# Epoch 010/50 | train_loss=0.4195 train_acc=88.28% | val_loss=0.6598 val_acc=77.50%
# Epoch 11/50: 100% 352/352 [00:11<00:00, 31.47it/s]
# Epoch 011/50 | train_loss=0.3960 train_acc=89.04% | val_loss=0.7323 val_acc=76.82%
# Epoch 12/50: 100% 352/352 [00:11<00:00, 31.61it/s]
# Epoch 012/50 | train_loss=0.3521 train_acc=89.71% | val_loss=0.9303 val_acc=74.16%
# Epoch 13/50: 100% 352/352 [00:11<00:00, 30.87it/s]
# Epoch 013/50 | train_loss=0.3137 train_acc=90.09% | val_loss=0.5936 val_acc=80.70%
# Epoch 14/50: 100% 352/352 [00:10<00:00, 32.42it/s]
# Epoch 014/50 | train_loss=0.2941 train_acc=90.76% | val_loss=0.6658 val_acc=78.76%
# Epoch 15/50: 100% 352/352 [00:11<00:00, 31.24it/s]
# Epoch 015/50 | train_loss=0.2832 train_acc=91.17% | val_loss=0.8182 val_acc=74.60%
# Epoch 16/50: 100% 352/352 [00:12<00:00, 29.29it/s]
# Epoch 016/50 | train_loss=0.2694 train_acc=91.66% | val_loss=0.6925 val_acc=77.94%
# Epoch 17/50: 100% 352/352 [00:11<00:00, 30.45it/s]
# Epoch 017/50 | train_loss=0.2655 train_acc=91.64% | val_loss=0.6872 val_acc=78.74%
# Epoch 18/50: 100% 352/352 [00:11<00:00, 31.98it/s]
# Epoch 018/50 | train_loss=0.2596 train_acc=91.90% | val_loss=0.6715 val_acc=79.06%
# Epoch 19/50: 100% 352/352 [00:10<00:00, 32.43it/s]
# Epoch 019/50 | train_loss=0.2532 train_acc=92.19% | val_loss=0.6430 val_acc=80.06%
# Epoch 20/50: 100% 352/352 [00:11<00:00, 31.13it/s]
# Epoch 020/50 | train_loss=0.2559 train_acc=92.06% | val_loss=0.8390 val_acc=74.60%
# Epoch 21/50: 100% 352/352 [00:11<00:00, 31.82it/s]
# Epoch 021/50 | train_loss=0.2429 train_acc=92.61% | val_loss=0.6474 val_acc=80.44%
# Epoch 22/50: 100% 352/352 [00:10<00:00, 32.22it/s]
# Epoch 022/50 | train_loss=0.2498 train_acc=92.30% | val_loss=0.6210 val_acc=80.64%
# Epoch 23/50: 100% 352/352 [00:10<00:00, 32.47it/s]
# Epoch 023/50 | train_loss=0.2348 train_acc=92.74% | val_loss=0.6344 val_acc=79.76%
# Epoch 24/50: 100% 352/352 [00:11<00:00, 30.64it/s]
# Epoch 024/50 | train_loss=0.2331 train_acc=92.71% | val_loss=0.7262 val_acc=78.06%
# Epoch 25/50: 100% 352/352 [00:11<00:00, 30.39it/s]
# Epoch 025/50 | train_loss=0.2333 train_acc=92.67% | val_loss=0.6670 val_acc=80.04%
# Epoch 26/50: 100% 352/352 [00:11<00:00, 30.71it/s]
# Epoch 026/50 | train_loss=0.2270 train_acc=93.13% | val_loss=0.6150 val_acc=81.02%
# Saved checkpoint: SparseMoE val_acc=81.02%
# Epoch 27/50: 100% 352/352 [00:11<00:00, 30.08it/s]
# Epoch 027/50 | train_loss=0.2256 train_acc=93.06% | val_loss=0.8519 val_acc=76.04%
# Epoch 28/50: 100% 352/352 [00:11<00:00, 31.85it/s]
# Epoch 028/50 | train_loss=0.2343 train_acc=92.90% | val_loss=0.7528 val_acc=78.14%
# Epoch 29/50: 100% 352/352 [00:11<00:00, 30.06it/s]
# Epoch 029/50 | train_loss=0.2182 train_acc=93.38% | val_loss=0.7092 val_acc=78.10%
# Epoch 30/50: 100% 352/352 [00:11<00:00, 31.84it/s]
# Epoch 030/50 | train_loss=0.2309 train_acc=92.91% | val_loss=0.6457 val_acc=80.16%
# Epoch 31/50: 100% 352/352 [00:10<00:00, 32.01it/s]
# Epoch 031/50 | train_loss=0.0689 train_acc=98.32% | val_loss=0.4062 val_acc=87.32%
# Saved checkpoint: SparseMoE val_acc=87.32%
# Epoch 32/50: 100% 352/352 [00:10<00:00, 32.10it/s]
# Epoch 032/50 | train_loss=0.0265 train_acc=99.68% | val_loss=0.4067 val_acc=87.88%
# Saved checkpoint: SparseMoE val_acc=87.88%
# Epoch 33/50: 100% 352/352 [00:10<00:00, 32.40it/s]
# Epoch 033/50 | train_loss=0.0181 train_acc=99.90% | val_loss=0.4181 val_acc=87.72%
# Epoch 34/50: 100% 352/352 [00:11<00:00, 31.51it/s]
# Epoch 034/50 | train_loss=0.0153 train_acc=99.94% | val_loss=0.4238 val_acc=87.88%
# Epoch 35/50: 100% 352/352 [00:10<00:00, 32.55it/s]
# Epoch 035/50 | train_loss=0.0141 train_acc=99.96% | val_loss=0.4257 val_acc=88.02%
# Saved checkpoint: SparseMoE val_acc=88.02%
# Epoch 36/50: 100% 352/352 [00:11<00:00, 31.18it/s]
# Epoch 036/50 | train_loss=0.0135 train_acc=99.98% | val_loss=0.4309 val_acc=87.80%
# Epoch 37/50: 100% 352/352 [00:10<00:00, 32.41it/s]
# Epoch 037/50 | train_loss=0.0129 train_acc=99.98% | val_loss=0.4317 val_acc=87.80%
# Epoch 38/50: 100% 352/352 [00:11<00:00, 31.38it/s]
# Epoch 038/50 | train_loss=0.0127 train_acc=99.97% | val_loss=0.4327 val_acc=87.92%
# Epoch 39/50: 100% 352/352 [00:10<00:00, 32.60it/s]
# Epoch 039/50 | train_loss=0.0119 train_acc=99.97% | val_loss=0.4307 val_acc=87.94%
# Epoch 40/50: 100% 352/352 [00:11<00:00, 31.74it/s]
# Epoch 040/50 | train_loss=0.0121 train_acc=99.99% | val_loss=0.4341 val_acc=87.74%
# Epoch 41/50: 100% 352/352 [00:11<00:00, 31.91it/s]
# Epoch 041/50 | train_loss=0.0120 train_acc=99.99% | val_loss=0.4340 val_acc=87.76%
# Epoch 42/50: 100% 352/352 [00:10<00:00, 32.23it/s]
# Epoch 042/50 | train_loss=0.0117 train_acc=99.98% | val_loss=0.4362 val_acc=87.98%
# Epoch 43/50: 100% 352/352 [00:11<00:00, 30.51it/s]
# Epoch 043/50 | train_loss=0.0116 train_acc=99.98% | val_loss=0.4262 val_acc=88.12%
# Saved checkpoint: SparseMoE val_acc=88.12%
# Epoch 44/50: 100% 352/352 [00:11<00:00, 31.31it/s]
# Epoch 044/50 | train_loss=0.0108 train_acc=100.00% | val_loss=0.4356 val_acc=87.70%
# Epoch 45/50: 100% 352/352 [00:10<00:00, 32.32it/s]
# Epoch 045/50 | train_loss=0.0117 train_acc=99.99% | val_loss=0.4373 val_acc=87.84%
# Epoch 46/50: 100% 352/352 [00:11<00:00, 31.73it/s]
# Epoch 046/50 | train_loss=0.0118 train_acc=99.99% | val_loss=0.4331 val_acc=88.16%
# Saved checkpoint: SparseMoE val_acc=88.16%
# Epoch 47/50: 100% 352/352 [00:10<00:00, 32.77it/s]
# Epoch 047/50 | train_loss=0.0118 train_acc=99.99% | val_loss=0.4313 val_acc=88.02%
# Epoch 48/50: 100% 352/352 [00:11<00:00, 31.36it/s]
# Epoch 048/50 | train_loss=0.0113 train_acc=100.00% | val_loss=0.4346 val_acc=87.80%
# Epoch 49/50: 100% 352/352 [00:11<00:00, 30.59it/s]
# Epoch 049/50 | train_loss=0.0112 train_acc=99.99% | val_loss=0.4277 val_acc=87.92%
# Epoch 50/50: 100% 352/352 [00:10<00:00, 32.36it/s]
# Epoch 050/50 | train_loss=0.0112 train_acc=99.99% | val_loss=0.4322 val_acc=88.00%
# [FINAL TEST] loss=0.4657 acc=87.17%
#
# === Summary ===
# num_experts 8
# top_k       2
# expert_width 64
# total_width  512
# M_A  (max train acc): 100.00%  at epoch 44
# G_A  (max val  acc): 88.16%  at epoch 46
# ETT(M_A) = 44,  ETT(G_A) = 46
