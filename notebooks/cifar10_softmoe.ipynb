# %% [markdown]
# # CIFAR-10_comparison_runs
#
# Setup, train, and visualize metrics.

# %%
# Start clean
# %cd /
# !rm -rf /content/mixture-of-experts-project
# %cd /content

# Clone the repo
# !git clone https://github.com/moe-project-uu/mixture-of-experts-project.git
# %cd mixture-of-experts-project

# Checkout 
# !git checkout -f arokah
# !git branch   # (just to confirm you're on 'arokah')

# Install dependencies + editable package
# %pip install -r requirements.txt
# %pip install -U pip
# %pip install -e .
# Out:
# [Errno 2] No such file or directory: '/content # go back to root'
# /content
# Cloning into 'mixture-of-experts-project'...
# remote: Enumerating objects: 408, done.
# remote: Counting objects: 100% (193/193), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 408 (delta 101), reused 122 (delta 50), pack-reused 215 (from 1)
# Receiving objects: 100% (408/408), 22.97 MiB | 43.16 MiB/s, done.
# Resolving deltas: 100% (196/196), done.
# /content/mixture-of-experts-project
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.23.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.8.0+cu126)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (1.16.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (0.13.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (4.67.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (2.2.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (2.19.0)
# Collecting lightning (from -r requirements.txt (line 12))
#   Downloading lightning-2.5.5-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (0.8.1)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (2.37.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->-r requirements.txt (line 2)) (11.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 6)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 10)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 10)) (2025.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 11)) (1.75.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 11)) (3.9)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 11)) (5.29.5)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 11)) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 11)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->-r requirements.txt (line 11)) (3.1.3)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/dist-packages (from lightning->-r requirements.txt (line 12)) (6.0.3)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning->-r requirements.txt (line 12))
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting torchmetrics<3.0,>0.7.0 (from lightning->-r requirements.txt (line 12))
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Collecting pytorch-lightning (from lightning->-r requirements.txt (line 12))
#   Downloading pytorch_lightning-2.5.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning->-r requirements.txt (line 12)) (3.13.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard->-r requirements.txt (line 11)) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->-r requirements.txt (line 12)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->-r requirements.txt (line 12)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->-r requirements.txt (line 12)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->-r requirements.txt (line 12)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->-r requirements.txt (line 12)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->-r requirements.txt (line 12)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->-r requirements.txt (line 12)) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->-r requirements.txt (line 12)) (3.11)
# Downloading lightning-2.5.5-py3-none-any.whl (828 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 828.5/828.5 kB 19.5 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 51.3 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.5-py3-none-any.whl (832 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.4/832.4 kB 64.6 MB/s eta 0:00:00
# Installing collected packages: lightning-utilities, torchmetrics, pytorch-lightning, lightning
# Successfully installed lightning-2.5.5 lightning-utilities-0.15.2 pytorch-lightning-2.5.5 torchmetrics-1.8.2
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 24.7 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-25.2
# Obtaining file:///content/mixture-of-experts-project
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from mixture-of-experts-project==0.0.1) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from mixture-of-experts-project==0.0.1) (0.23.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from mixture-of-experts-project==0.0.1) (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mixture-of-experts-project==0.0.1) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->mixture-of-experts-project==0.0.1) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->mixture-of-experts-project==0.0.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->mixture-of-experts-project==0.0.1) (3.0.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->mixture-of-experts-project==0.0.1) (11.3.0)
# Building wheels for collected packages: mixture-of-experts-project
#   Building editable for mixture-of-experts-project (pyproject.toml) ... done
#   Created wheel for mixture-of-experts-project: filename=mixture_of_experts_project-0.0.1-0.editable-py3-none-any.whl size=2329 sha256=c2c8805d7c94ea695ea50bacce4373aea767f92635936e6cb2b9d2b3ee5c245f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9m8yw61l/wheels/ae/11/13/3f39235c020980092487306de3ad3cb6716082c994d77afddc
# Successfully built mixture-of-experts-project
# Installing collected packages: mixture-of-experts-project
# Successfully installed mixture-of-experts-project-0.0.1

# %%
# Train via CLI so argparse is used
# %cd /content/mixture-of-experts-project

# !python scripts/train_cifar10.py --FF_layer SparseMoE --epochs 50 --num_experts 16 --dropout_p 0.1 --temperature 1 --sparsemoe_importance_coef 0.2 --sparsemoe_load_coef 0.2
# Out:
# Branch 'arokah' set up to track remote branch 'arokah' from 'origin'.
# Switched to a new branch 'arokah'
# * arokah
#   main

# %%
# Load metrics.pt and plot loss/accuracy
import os, torch, numpy as np
import matplotlib.pyplot as plt

# Must match the run config
FF_LAYER = "SparseMoE"
EPOCHS   = 50
NUM_EXPERTS = 16
SPARSEMOE_K = 2


# Mirror train_cifar10.py logic
if FF_LAYER == "Dense":
    run_tag = f"E{EPOCHS}"
elif FF_LAYER == "SparseMoE":
    run_tag = f"E{EPOCHS}-X{NUM_EXPERTS}-K{SPARSEMOE_K}"
else:
    run_tag = f"E{EPOCHS}-X{NUM_EXPERTS}"


ckpt_dir = os.path.join("/content/mixture-of-experts-project", "checkpoints", FF_LAYER, run_tag)
metrics_path = os.path.join(ckpt_dir, "metrics.pt")
assert os.path.exists(metrics_path), f"metrics.pt not found at {metrics_path}"

# load hist dict from metrics.pt
hist = torch.load(metrics_path, map_location="cpu", weights_only=False)



train_loss = np.array(hist["train_loss"])
train_acc  = np.array(hist["train_acc"])
val_loss   = np.array(hist["val_loss"])
val_acc    = np.array(hist["val_acc"])

plt.figure(figsize=(6,4))
plt.plot(train_loss, label="train")
plt.plot(val_loss,   label="val")
plt.xlabel("epoch"); plt.ylabel("loss"); plt.title(f"{FF_LAYER} — Loss"); plt.legend(); plt.show()

plt.figure(figsize=(6,4))
plt.plot(train_acc, label="train")
plt.plot(val_acc,   label="val")
plt.xlabel("epoch"); plt.ylabel("accuracy"); plt.title(f"{FF_LAYER} — Accuracy"); plt.legend(); plt.show()
# Out:
# /content/mixture-of-experts-project
# dataloaders metadata: {'mean': (0.4914, 0.4822, 0.4465), 'std': (0.247, 0.2435, 0.2616), 'num_classes': 10, 'sizes': {'train': 45000, 'val': 5000, 'test': 10000}}
# Epoch 1/50: 100% 352/352 [00:07<00:00, 48.92it/s]
# Epoch 001/50 | train_loss=1.6079 train_acc=41.06% | val_loss=1.4202 val_acc=48.98%
# Saved checkpoint: SoftMoE val_acc=48.98%
# Epoch 2/50: 100% 352/352 [00:06<00:00, 57.23it/s]
# Epoch 002/50 | train_loss=1.0313 train_acc=63.51% | val_loss=1.0293 val_acc=63.44%
# Saved checkpoint: SoftMoE val_acc=63.44%
# Epoch 3/50: 100% 352/352 [00:06<00:00, 57.24it/s]
# Epoch 003/50 | train_loss=0.7398 train_acc=74.58% | val_loss=0.7946 val_acc=72.24%
# Saved checkpoint: SoftMoE val_acc=72.24%
# Epoch 4/50: 100% 352/352 [00:06<00:00, 57.26it/s]
# Epoch 004/50 | train_loss=0.5858 train_acc=79.84% | val_loss=0.6682 val_acc=76.46%
# Saved checkpoint: SoftMoE val_acc=76.46%
# Epoch 5/50: 100% 352/352 [00:06<00:00, 57.31it/s]
# Epoch 005/50 | train_loss=0.4933 train_acc=83.04% | val_loss=0.7844 val_acc=73.56%
# Epoch 6/50: 100% 352/352 [00:06<00:00, 57.44it/s]
# Epoch 006/50 | train_loss=0.4285 train_acc=85.59% | val_loss=0.7065 val_acc=76.10%
# Epoch 7/50: 100% 352/352 [00:06<00:00, 57.64it/s]
# Epoch 007/50 | train_loss=0.3807 train_acc=87.10% | val_loss=0.5351 val_acc=81.18%
# Saved checkpoint: SoftMoE val_acc=81.18%
# Epoch 8/50: 100% 352/352 [00:06<00:00, 55.65it/s]
# Epoch 008/50 | train_loss=0.3424 train_acc=88.28% | val_loss=0.6711 val_acc=78.12%
# Epoch 9/50: 100% 352/352 [00:06<00:00, 56.65it/s]
# Epoch 009/50 | train_loss=0.3131 train_acc=89.28% | val_loss=0.7026 val_acc=78.28%
# Epoch 10/50: 100% 352/352 [00:06<00:00, 56.44it/s]
# Epoch 010/50 | train_loss=0.2964 train_acc=89.93% | val_loss=0.6966 val_acc=76.84%
# Epoch 11/50: 100% 352/352 [00:06<00:00, 57.19it/s]
# Epoch 011/50 | train_loss=0.2767 train_acc=90.71% | val_loss=0.7601 val_acc=75.62%
# Epoch 12/50: 100% 352/352 [00:06<00:00, 56.92it/s]
# Epoch 012/50 | train_loss=0.2542 train_acc=91.23% | val_loss=0.6453 val_acc=79.88%
# Epoch 13/50: 100% 352/352 [00:06<00:00, 56.20it/s]
# Epoch 013/50 | train_loss=0.2375 train_acc=91.98% | val_loss=0.6202 val_acc=80.38%
# Epoch 14/50: 100% 352/352 [00:06<00:00, 57.78it/s]
# Epoch 014/50 | train_loss=0.2269 train_acc=92.30% | val_loss=0.7107 val_acc=78.60%
# Epoch 15/50: 100% 352/352 [00:06<00:00, 57.16it/s]
# Epoch 015/50 | train_loss=0.2260 train_acc=92.42% | val_loss=0.7954 val_acc=75.42%
# Epoch 16/50: 100% 352/352 [00:06<00:00, 57.31it/s]
# Epoch 016/50 | train_loss=0.2198 train_acc=92.60% | val_loss=0.6908 val_acc=77.46%
# Epoch 17/50: 100% 352/352 [00:06<00:00, 56.77it/s]
# Epoch 017/50 | train_loss=0.2159 train_acc=92.59% | val_loss=1.1289 val_acc=69.34%
# Epoch 18/50: 100% 352/352 [00:06<00:00, 56.94it/s]
# Epoch 018/50 | train_loss=0.2094 train_acc=92.88% | val_loss=0.5915 val_acc=80.26%
# Epoch 19/50: 100% 352/352 [00:06<00:00, 57.22it/s]
# Epoch 019/50 | train_loss=0.2036 train_acc=93.01% | val_loss=0.6662 val_acc=79.10%
# Epoch 20/50: 100% 352/352 [00:06<00:00, 57.67it/s]
# Epoch 020/50 | train_loss=0.1963 train_acc=93.38% | val_loss=0.7357 val_acc=77.88%
# Epoch 21/50: 100% 352/352 [00:06<00:00, 57.24it/s]
# Epoch 021/50 | train_loss=0.1950 train_acc=93.46% | val_loss=0.6197 val_acc=80.42%
# Epoch 22/50: 100% 352/352 [00:06<00:00, 56.49it/s]
# Epoch 022/50 | train_loss=0.2010 train_acc=93.35% | val_loss=0.6452 val_acc=80.28%
# Epoch 23/50: 100% 352/352 [00:06<00:00, 56.60it/s]
# Epoch 023/50 | train_loss=0.1854 train_acc=93.88% | val_loss=0.6517 val_acc=80.26%
# Epoch 24/50: 100% 352/352 [00:06<00:00, 56.73it/s]
# Epoch 024/50 | train_loss=0.1897 train_acc=93.71% | val_loss=0.6447 val_acc=79.92%
# Epoch 25/50: 100% 352/352 [00:06<00:00, 56.34it/s]
# Epoch 025/50 | train_loss=0.1904 train_acc=93.65% | val_loss=0.7125 val_acc=78.82%
# Epoch 26/50: 100% 352/352 [00:06<00:00, 56.63it/s]
# Epoch 026/50 | train_loss=0.1852 train_acc=93.71% | val_loss=0.6607 val_acc=79.86%
# Epoch 27/50: 100% 352/352 [00:06<00:00, 57.11it/s]
# Epoch 027/50 | train_loss=0.1993 train_acc=93.31% | val_loss=0.7212 val_acc=78.20%
# Epoch 28/50: 100% 352/352 [00:06<00:00, 56.39it/s]
# Epoch 028/50 | train_loss=0.1830 train_acc=93.73% | val_loss=0.7258 val_acc=78.18%
# Epoch 29/50: 100% 352/352 [00:06<00:00, 56.87it/s]
# Epoch 029/50 | train_loss=0.1786 train_acc=94.02% | val_loss=0.6457 val_acc=80.20%
# Epoch 30/50: 100% 352/352 [00:06<00:00, 57.13it/s]
# Epoch 030/50 | train_loss=0.1820 train_acc=93.88% | val_loss=0.6496 val_acc=80.90%
# Epoch 31/50: 100% 352/352 [00:06<00:00, 57.54it/s]
# Epoch 031/50 | train_loss=0.0487 train_acc=98.66% | val_loss=0.4264 val_acc=87.10%
# Saved checkpoint: SoftMoE val_acc=87.10%
# Epoch 32/50: 100% 352/352 [00:06<00:00, 56.67it/s]
# Epoch 032/50 | train_loss=0.0129 train_acc=99.89% | val_loss=0.4253 val_acc=87.30%
# Saved checkpoint: SoftMoE val_acc=87.30%
# Epoch 33/50: 100% 352/352 [00:06<00:00, 57.31it/s]
# Epoch 033/50 | train_loss=0.0079 train_acc=99.98% | val_loss=0.4286 val_acc=87.36%
# Saved checkpoint: SoftMoE val_acc=87.36%
# Epoch 34/50: 100% 352/352 [00:06<00:00, 57.63it/s]
# Epoch 034/50 | train_loss=0.0061 train_acc=99.99% | val_loss=0.4298 val_acc=87.48%
# Saved checkpoint: SoftMoE val_acc=87.48%
# Epoch 35/50: 100% 352/352 [00:06<00:00, 56.95it/s]
# Epoch 035/50 | train_loss=0.0052 train_acc=99.99% | val_loss=0.4280 val_acc=87.52%
# Saved checkpoint: SoftMoE val_acc=87.52%
# Epoch 36/50: 100% 352/352 [00:06<00:00, 57.14it/s]
# Epoch 036/50 | train_loss=0.0047 train_acc=100.00% | val_loss=0.4274 val_acc=87.66%
# Saved checkpoint: SoftMoE val_acc=87.66%
# Epoch 37/50: 100% 352/352 [00:06<00:00, 55.82it/s]
# Epoch 037/50 | train_loss=0.0040 train_acc=100.00% | val_loss=0.4241 val_acc=87.68%
# Saved checkpoint: SoftMoE val_acc=87.68%
# Epoch 38/50: 100% 352/352 [00:06<00:00, 56.56it/s]
# Epoch 038/50 | train_loss=0.0040 train_acc=100.00% | val_loss=0.4266 val_acc=87.66%
# Epoch 39/50: 100% 352/352 [00:06<00:00, 57.51it/s]
# Epoch 039/50 | train_loss=0.0038 train_acc=100.00% | val_loss=0.4250 val_acc=87.76%
# Saved checkpoint: SoftMoE val_acc=87.76%
# Epoch 40/50: 100% 352/352 [00:06<00:00, 56.96it/s]
# Epoch 040/50 | train_loss=0.0036 train_acc=100.00% | val_loss=0.4223 val_acc=87.64%
# Epoch 41/50: 100% 352/352 [00:06<00:00, 57.48it/s]
# Epoch 041/50 | train_loss=0.0034 train_acc=100.00% | val_loss=0.4258 val_acc=87.68%
# Epoch 42/50: 100% 352/352 [00:06<00:00, 57.08it/s]
# Epoch 042/50 | train_loss=0.0034 train_acc=100.00% | val_loss=0.4220 val_acc=87.94%
# Saved checkpoint: SoftMoE val_acc=87.94%
# Epoch 43/50: 100% 352/352 [00:06<00:00, 57.33it/s]
# Epoch 043/50 | train_loss=0.0034 train_acc=100.00% | val_loss=0.4195 val_acc=87.78%
# Epoch 44/50: 100% 352/352 [00:06<00:00, 57.10it/s]
# Epoch 044/50 | train_loss=0.0034 train_acc=100.00% | val_loss=0.4197 val_acc=87.82%
# Epoch 45/50: 100% 352/352 [00:06<00:00, 57.34it/s]
# Epoch 045/50 | train_loss=0.0033 train_acc=100.00% | val_loss=0.4180 val_acc=87.88%
# Epoch 46/50: 100% 352/352 [00:06<00:00, 57.06it/s]
# Epoch 046/50 | train_loss=0.0033 train_acc=100.00% | val_loss=0.4240 val_acc=87.68%
# Epoch 47/50: 100% 352/352 [00:06<00:00, 56.27it/s]
# Epoch 047/50 | train_loss=0.0034 train_acc=100.00% | val_loss=0.4198 val_acc=87.76%
# Epoch 48/50: 100% 352/352 [00:06<00:00, 57.62it/s]
# Epoch 048/50 | train_loss=0.0034 train_acc=100.00% | val_loss=0.4247 val_acc=87.70%
# Epoch 49/50: 100% 352/352 [00:06<00:00, 56.47it/s]
# Epoch 049/50 | train_loss=0.0034 train_acc=100.00% | val_loss=0.4215 val_acc=87.88%
# Epoch 50/50: 100% 352/352 [00:06<00:00, 56.31it/s]
# Epoch 050/50 | train_loss=0.0034 train_acc=100.00% | val_loss=0.4214 val_acc=87.86%
# [FINAL TEST] loss=0.4480 acc=87.32%
#
# === Summary ===
# num_experts 4
# expert_width 1024
# total_width  4096
# M_A  (max train acc): 100.00%  at epoch 36
# G_A  (max val  acc): 87.94%  at epoch 42
# ETT(M_A) = 36,  ETT(G_A) = 42

# %%
# Expert Utilization

from moe.utils.helpers import plot_expert_utilization
plot_expert_utilization(hist, ff_layer=FF_LAYER, epochs_to_bar=(0, 25, 49))

# %%
# Gating Entropy
from src.moe.utils.helpers import plot_gating_entropy
plot_gating_entropy(hist, ff_layer=FF_LAYER)

# %%
from src.moe.utils.helpers import plot_expert_probs_by_class, plot_expert_probs_heatmap

class_expert_mean = hist.get("class_expert_mean", None)
class_names = hist.get("class_names", None)

if class_expert_mean is None:
    print("No 'class_expert_mean' found in metrics. Make sure you ran SoftMoE and Step 1 code saved it.")
else:
    plot_expert_probs_by_class(class_expert_mean, class_names, ff_layer=FF_LAYER)
    plot_expert_probs_heatmap(class_expert_mean, class_names, ff_layer=FF_LAYER)

# %%
#gating network utilization on test set with learned model
from src.moe.utils.helpers import plot_expert_utilization_snapshot

if "util_test_snapshot" in hist:
    plot_expert_utilization_snapshot(hist["util_test_snapshot"], ff_layer=FF_LAYER)
else:
    print("No test snapshot found in metrics.pt — run the new test snapshot code first.")

# %% [markdown]
# #Now visualizing actual load balannce --above is probability balance

# %%
from moe.utils.helpers import (
    plot_expert_utilization_snapshot,
    plot_expert_load_over_epochs,
)

plot_expert_load_over_epochs(hist, ff_layer=FF_LAYER)
plot_expert_utilization_snapshot(hist["util_test_snapshot"], ff_layer=FF_LAYER)
