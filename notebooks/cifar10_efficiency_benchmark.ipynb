# %% [markdown]
# # CIFAR-10 Inference Efficiency Benchmark (Dense vs SoftMoE vs SparseMoE)
#
# This notebook runs `scripts/cifar10_efficiency.py` for trained CIFAR-10 checkpoints and aggregates the results.

# %%
import os, json, subprocess
import pandas as pd
import torch

# ---- EDIT THIS PATH ----
# If you opened from GitHub and cloned manually, set REPO_ROOT accordingly.
# Example: REPO_ROOT = '/content/mixture-of-experts-project'
REPO_ROOT = '/content/mixture-of-experts-project'
# ------------------------

os.chdir(REPO_ROOT)
print('CWD:', os.getcwd())
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))

CKPT_DIRS = {
    'Dense':     'checkpoints/cifar/Dense/E50',
    'SoftMoE':   'checkpoints/cifar/SoftMoE/E50-X8',
    'SparseMoE': 'checkpoints/cifar/SparseMoE/E50-X8-K2',
}

for k, v in CKPT_DIRS.items():
    print(k, '->', v, '| exists:', os.path.exists(v))
